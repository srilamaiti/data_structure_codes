# %% [markdown]
# <a href="https://colab.research.google.com/github/srilamaiti/data_structure_codes/blob/main/merge_sort.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pdb
import sys
import trace

# %%
# Python program for implementation of MergeSort
def mergeSort(arr):
    if len(arr) > 1:
 
         # Finding the mid of the array
        mid = len(arr)//2
 
        # Dividing the array elements
        L = arr[:mid]
 
        # into 2 halves
        R = arr[mid:]
 
        # Sorting the first half
        mergeSort(L)
 
        # Sorting the second half
        mergeSort(R)
 
        i = j = k = 0
 
        # Copy data to temp arrays L[] and R[]
        while i < len(L) and j < len(R):
            if L[i] <= R[j]:
                arr[k] = L[i]
                i += 1
            else:
                arr[k] = R[j]
                j += 1
            k += 1
 
        # Checking if any element was left
        while i < len(L):
            arr[k] = L[i]
            i += 1
            k += 1
 
        while j < len(R):
            arr[k] = R[j]
            j += 1
            k += 1
 
# Code to print the list
 
 
def printList(arr):
    for i in range(len(arr)):
        print(arr[i], end=" ")
    print()
 

# Driver Code
def main():
    arr = [12, 11, 13, 5, 6, 7]
    print("Given array is", end="\n")
    printList(arr)
    mergeSort(arr)
    print("Sorted array is: ", end="\n")
    printList(arr)

# %%
# create a Trace object, telling it what to ignore, and whether to
# do tracing or line-counting or both.
tracer = trace.Trace(
    #ignoredirs=[sys.prefix,
    #sys.exec_prefix
    #],
    #trace=1,
    #count=1
    )

# %%
# run the new command using the given tracer
tracer.run('main()')
# Out:
#  --- modulename: iostream, funcname: write
# iostream.py(387):         if self.echo is not None:
# iostream.py(395):         if self.pub_thread is None:
# iostream.py(399):             if not isinstance(string, unicode_type):
# iostream.py(402):             is_child = (not self._is_master_process())
#  --- modulename: iostream, funcname: _is_master_process
# iostream.py(311):         return os.getpid() == self._master_pid
# iostream.py(404):             self.pub_thread.schedule(lambda : self._buffer.write(string))
#  --- modulename: iostream, funcname: schedule
# iostream.py(202):         if self.thread.is_alive():
#  --- modulename: threading, funcname: is_alive
# threading.py(1079):         assert self._initialized, "Thread.__init__() not called"
# threading.py(1080):         if self._is_stopped or not self._started.is_set():
#  --- modulename: threading, funcname: is_set
# threading.py(515):         return self._flag
# threading.py(1082):         self._wait_for_tstate_lock(False)
# ...

# %%
# make a report, placing output in the current directory
r = tracer.results()
r.write_results(show_missing=True, coverdir=".")

# %%
r
